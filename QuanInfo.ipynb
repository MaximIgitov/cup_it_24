# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data.csv", parse_dates=["date_of", "ctl_loading_date"])
df_no_dub = df.drop_duplicates(subset=["ctl_loading", "benchmark_id"])
weak_df_no_dub = df.drop_duplicates(subset=["ctl_loading", "benchmark_id", "quote"])
df_no_dub
# Out:
#                                 benchmark_id  \
# 0       00000000-0000-0000-0000-000000000001
# 1       005F4F7B-D562-4B0F-BDC9-EB892065A955
# 2       03B447D1-2B2D-4AC2-90C1-5DF2935D4FD1
# 3       050C195A-1D74-402F-B36D-63CA40AFE789
# 5       0532FCD2-5A26-4ED7-83C1-F482BE949312
# ...                                      ...
# 994999  F68E9BE2-B3A2-4923-B648-14C424A84EF0
# 995000  F846C875-184D-4862-8C0E-5A5D58E4FD20
# 995001  FB5DFAD6-CF72-4C1A-B78C-EE42A1D0BFE0
# 995002  FCE411C7-6A5C-4AB3-8626-070844143139
# 995003  FDD3894E-BD97-45DB-B236-A2DB271FFFDA
#
#                                            benchmark_name    date_of  \
# 0                                                  Ruonia 2018-04-09
# 1                                               RUGBITR1Y 2018-04-09
# 2                        50%RUCBITRBB3Y + 50%RUCBITRBBB3Y 2018-04-09
# 3                          60% RUGBITR1Y+40% RUONIA Index 2018-04-09
# 5       30.00%RUGBITR1Y + 1.10%ОФЗ-29006 + 68.90%ОФЗ-2... 2018-04-09
# ...                                                   ...        ...
# 994999                                          ОФЗ 24021 2024-03-15
# 995000                50%*RUGBITR3Y + 50%*Ставка 12.4174% 2024-03-15
# 995001                                        Ставка 7,7% 2024-03-15
# 995002                                          MBI TR 3Y 2024-03-15
# 995003                             70% EMCR + 30% B13TTRU 2024-03-15
#
#               quote  ctl_loading ctl_loading_date
# 0        513.893595  38463471715       2018-04-09
# 1        153.916680  38463471715       2018-04-09
# 2         48.649655  38463471715       2018-04-09
# 3        277.774791  38463471715       2018-04-09
# 5         63.836133  38463471715       2018-04-09
# ...             ...          ...              ...
# 994999   861.989892  83427809714       2024-03-15
# 995000     7.639006  83427809714       2024-03-15
# 995001     2.477175  83427809714       2024-03-15
# 995002  1493.885023  83427809714       2024-03-15
# 995003   198.669337  83427809714       2024-03-15
#
# [928150 rows x 6 columns]

# %%
df[df.duplicated(subset=["ctl_loading", "benchmark_id"], keep=False)].iloc[:20,:]
# Out:
#                              benchmark_id  \
# 3    050C195A-1D74-402F-B36D-63CA40AFE789
# 4    050C195A-1D74-402F-B36D-63CA40AFE789
# 16   116EAE8B-E5FC-439C-9EC0-8E92847DE3E4
# 20   195A80D0-7E3F-426A-9E0F-F6A406AAA404
# 29   1E2B2513-EAE7-4FD3-BD05-EB0A57BE3B2A
# 37   25922DE3-A09E-45BA-A809-CFF3DD90E5B5
# 49   2D49912D-5D16-42E2-857B-B591DBFB88EB
# 51   2D61CE65-7ED2-4361-9DC4-74739A4DE2D1
# 76   46CBA86E-0269-4219-88C8-AE52B4CCD142
# 77   46CBA86E-0269-4219-88C8-AE52B4CCD142
# 88   506BA5FE-BF38-46C2-873A-D6DACE1BA323
# 116  6E2BEFD3-0DC7-4B3B-98CC-E669B2566D52
# 119  6EC20EBD-AD0E-4985-A1B0-B656480397C6
# 122  712E0550-C2E7-49B4-A365-1EEFC6CB7FE2
# 152  8D8AADAB-A754-4C02-9C81-0E0B4890856B
# 153  8DA52C4D-DDC4-43A9-A5B3-A70C3AEAE1D4
# 154  8DA52C4D-DDC4-43A9-A5B3-A70C3AEAE1D4
# 157  90AA2A8A-CAD9-4B15-87A7-490B0A6BA7B5
# 158  90AA2A8A-CAD9-4B15-87A7-490B0A6BA7B5
# 176  A0CD2240-F684-4875-8662-5A47FCB17FC0
#
#                                         benchmark_name    date_of       quote  \
# 3                       60% RUGBITR1Y+40% RUONIA Index 2018-04-09  277.774791
# 4                       60% RUGBITR1Y+40% RUONIA Index 2018-04-09  277.774791
# 16   Индекс МосБиржи TR «нетто» (налог ставк росс орг) 2018-04-09  660.714777
# 20                                   Ставка 8% депозит 2018-04-09  153.470044
# 29                             80% MEOGTR + 20% MEMMTR 2018-04-09   12.505678
# 37   60% DAX Index + 20% MSCI Switzerland +20% FTSE... 2018-04-09    4.676401
# 49                          30% MCFTR + 70% RUCBTR3YNS 2018-04-09  293.976188
# 51                   Индекс МосБиржи полной доходности 2018-04-09   16.975784
# 76            iShares Core MSCI Emerging Markets ETF_2 2018-04-09   70.357246
# 77            iShares Core MSCI Emerging Markets ETF_2 2018-04-09   79.634180
# 88         7.5%MEBCTR + 85%RUCBITRBBB + 7.5% RUGBITR1Y 2018-04-09  649.653529
# 116             iShares Core MSCI Emerging Markets ETF 2018-04-09  323.099579
# 119   60%DAX Index + 20%MSDESZN Index + 20%TUKXG Index 2018-04-09  575.038901
# 122                NPF.SBER.1 (Индекс рассчитанный УК) 2018-04-09  205.978229
# 152                     Technology Select Sector Index 2018-04-09  114.034710
# 153                        50% RUCBTRAAANS + 50% MCFTR 2018-04-09   14.401664
# 154                        50% RUCBTRAAANS + 50% MCFTR 2018-04-09   14.401664
# 157                        80% RUCBTRAAANS + 20% MCFTR 2018-04-09   84.291281
# 158                        80% RUCBTRAAANS + 20% MCFTR 2018-04-09   93.124426
# 176                        65% RUCBTRAAANS + 35% MCFTR 2018-04-09   41.785606
#
#      ctl_loading ctl_loading_date
# 3    38463471715       2018-04-09
# 4    38463471715       2018-04-09
# 16   38463471715       2018-04-09
# 20   38463471715       2018-04-09
# 29   38463471715       2018-04-09
# 37   38463471715       2018-04-09
# 49   38463471715       2018-04-09
# 51   38463471715       2018-04-09
# 76   38463471715       2018-04-09
# 77   38463471715       2018-04-09
# 88   38463471715       2018-04-09
# 116  38463471715       2018-04-09
# 119  38463471715       2018-04-09
# 122  38463471715       2018-04-09
# 152  38463471715       2018-04-09
# 153  38463471715       2018-04-09
# 154  38463471715       2018-04-09
# 157  38463471715       2018-04-09
# 158  38463471715       2018-04-09
# 176  38463471715       2018-04-09

# %%
concat_list = []
for loading in df["ctl_loading"].unique():
    quote_date = df[df["ctl_loading"] == loading]["date_of"].unique()[0]
    loading_date = df[df["ctl_loading"] == loading]["ctl_loading_date"].unique()[0]
    new_df = df[((df["date_of"] == quote_date) & (df["ctl_loading_date"] < loading_date)) | (df["ctl_loading"] == loading)]
    new_df.loc[:,"ctl_loading"] = loading
    concat_list.append(new_df)
new_concat_df = pd.concat(concat_list)
new_concat_df
# Out:
# C:\Users\Максем\AppData\Local\Temp\ipykernel_13952\2049339586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.loc[:,"ctl_loading"] = loading
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\cup_it_24\QuanInfo.ipynb Ячейка 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/cup_it_24/QuanInfo.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     loading_date = df[df["ctl_loading"] == loading]["ctl_loading_date"].unique()[0]
#       <a href='vscode-notebook-cell:/d%3A/cup_it_24/QuanInfo.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     new_df = df[((df["date_of"] == quote_date) & (df["ctl_loading_date"] < loading_date)) | (df["ctl_loading"] == loading)]
# ----> <a href='vscode-notebook-cell:/d%3A/cup_it_24/QuanInfo.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>     new_df.loc[:,"ctl_loading"] = loading
#       <a href='vscode-notebook-cell:/d%3A/cup_it_24/QuanInfo.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>     concat_list.append(new_df)
#       <a href='vscode-notebook-cell:/d%3A/cup_it_24/QuanInfo.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> new_concat_df = pd.concat(concat_list)
#
# File c:\Users\anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\anaconda3\lib\site-packages\pandas\core\indexing.py:1688, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1685 # align and set the values
#    1686 if take_split_path:
#    1687     # We have to operate column-wise
# -> 1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
#    1690     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\anaconda3\lib\site-packages\pandas\core\indexing.py:1779, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1775 else:
#    1776
#    1777     # scalar value
#    1778     for loc in ilocs:
# -> 1779         self._setitem_single_column(loc, value, pi)
#
# File c:\Users\anaconda3\lib\site-packages\pandas\core\indexing.py:1895, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    1892     return
#    1894 # reset the sliced object if unique
# -> 1895 self.obj._iset_item(loc, ser)
#
# File c:\Users\anaconda3\lib\site-packages\pandas\core\frame.py:3820, in DataFrame._iset_item(self, loc, value)
#    3816 # check if we are modifying a copy
#    3817 # try to set first as we want an invalid
#    3818 # value exception to occur first
#    3819 if len(self):
# -> 3820     self._check_setitem_copy()
#
# File c:\Users\anaconda3\lib\site-packages\pandas\core\generic.py:4018, in NDFrame._check_setitem_copy(self, t, force)
#    4016     raise com.SettingWithCopyError(t)
#    4017 elif value == "warn":
# -> 4018     warnings.warn(t, com.SettingWithCopyWarning, stacklevel=find_stack_level())
#
# File c:\Users\anaconda3\lib\site-packages\pandas\util\_exceptions.py:32, in find_stack_level()
#      27 def find_stack_level() -> int:
#      28     """
#      29     Find the first place in the stack that is not inside pandas
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      34     import pandas as pd
#      36     pkg_dir = os.path.dirname(pd.__file__)
#
# File c:\Users\anaconda3\lib\inspect.py:1554, in stack(context)
#    1552 def stack(context=1):
#    1553     """Return a list of records for the stack above the caller's frame."""
# -> 1554     return getouterframes(sys._getframe(1), context)
#
# File c:\Users\anaconda3\lib\inspect.py:1531, in getouterframes(frame, context)
#    1529 framelist = []
#    1530 while frame:
# -> 1531     frameinfo = (frame,) + getframeinfo(frame, context)
#    1532     framelist.append(FrameInfo(*frameinfo))
#    1533     frame = frame.f_back
#
# File c:\Users\anaconda3\lib\inspect.py:1501, in getframeinfo(frame, context)
#    1498 if not isframe(frame):
#    1499     raise TypeError('{!r} is not a frame or traceback object'.format(frame))
# -> 1501 filename = getsourcefile(frame) or getfile(frame)
#    1502 if context > 0:
#    1503     start = lineno - 1 - context//2
#
# File c:\Users\anaconda3\lib\inspect.py:706, in getsourcefile(object)
#     703 elif any(filename.endswith(s) for s in
#     704              importlib.machinery.EXTENSION_SUFFIXES):
#     705     return None
# --> 706 if os.path.exists(filename):
#     707     return filename
#     708 # only return a non-existent filename if the module has a PEP 302 loader
#
# File c:\Users\anaconda3\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
new_concat_df.reset_index(inplace=True)
new_concat_df.sort_values(by=["ctl_loading_date"], ascending=True)
new_concat_df
# Out:
#           index                          benchmark_id  \
# 0             0  00000000-0000-0000-0000-000000000001
# 1             1  005F4F7B-D562-4B0F-BDC9-EB892065A955
# 2             2  03B447D1-2B2D-4AC2-90C1-5DF2935D4FD1
# 3             3  050C195A-1D74-402F-B36D-63CA40AFE789
# 4             4  050C195A-1D74-402F-B36D-63CA40AFE789
# ...         ...                                   ...
# 1044381  994999  F68E9BE2-B3A2-4923-B648-14C424A84EF0
# 1044382  995000  F846C875-184D-4862-8C0E-5A5D58E4FD20
# 1044383  995001  FB5DFAD6-CF72-4C1A-B78C-EE42A1D0BFE0
# 1044384  995002  FCE411C7-6A5C-4AB3-8626-070844143139
# 1044385  995003  FDD3894E-BD97-45DB-B236-A2DB271FFFDA
#
#                               benchmark_name    date_of        quote  \
# 0                                     Ruonia 2018-04-09   513.893595
# 1                                  RUGBITR1Y 2018-04-09   153.916680
# 2           50%RUCBITRBB3Y + 50%RUCBITRBBB3Y 2018-04-09    48.649655
# 3             60% RUGBITR1Y+40% RUONIA Index 2018-04-09   277.774791
# 4             60% RUGBITR1Y+40% RUONIA Index 2018-04-09   277.774791
# ...                                      ...        ...          ...
# 1044381                            ОФЗ 24021 2024-03-15   861.989892
# 1044382  50%*RUGBITR3Y + 50%*Ставка 12.4174% 2024-03-15     7.639006
# 1044383                          Ставка 7,7% 2024-03-15     2.477175
# 1044384                            MBI TR 3Y 2024-03-15  1493.885023
# 1044385               70% EMCR + 30% B13TTRU 2024-03-15   198.669337
#
#          ctl_loading ctl_loading_date
# 0        38463471715       2018-04-09
# 1        38463471715       2018-04-09
# 2        38463471715       2018-04-09
# 3        38463471715       2018-04-09
# 4        38463471715       2018-04-09
# ...              ...              ...
# 1044381  83427809714       2024-03-15
# 1044382  83427809714       2024-03-15
# 1044383  83427809714       2024-03-15
# 1044384  83427809714       2024-03-15
# 1044385  83427809714       2024-03-15
#
# [1044386 rows x 7 columns]

# %%
new_concat_df.drop(columns=["index"], inplace=True)

# %%
df_no_dublicates = new_concat_df.drop_duplicates(subset=["ctl_loading", "benchmark_id"], keep='last')
weak_df_no_dublicates = new_concat_df.drop_duplicates(subset=["ctl_loading", "benchmark_id", "quote"], keep='last')

# %%
aggregated_quantity = new_concat_df.groupby(["ctl_loading"]).size()
aggregated_quantity
# Out:
# ctl_loading
# 164246313      456
# 185831633      450
# 371367084      458
# 376949875      471
# 407853497      463
#               ...
# 98292180110    455
# 98315908034    425
# 98338898542    451
# 98357067480    458
# 98467715900    447
# Length: 2295, dtype: int64

# %%
aggregated_quantity_no_dublicates = df_no_dublicates.groupby(["ctl_loading"]).size()
aggregated_quantity_no_dublicates
# Out:
# ctl_loading
# 164246313      422
# 185831633      399
# 371367084      424
# 376949875      441
# 407853497      433
#               ...
# 98292180110    426
# 98315908034    398
# 98338898542    417
# 98357067480    427
# 98467715900    418
# Length: 2295, dtype: int64

# %%
weak_aggregated_quantity_no_dublicates = weak_df_no_dublicates.groupby(["ctl_loading"]).size()
weak_aggregated_quantity_no_dublicates
# Out:
# ctl_loading
# 164246313      431
# 185831633      435
# 371367084      430
# 376949875      450
# 407853497      450
#               ...
# 98292180110    431
# 98315908034    412
# 98338898542    422
# 98357067480    435
# 98467715900    426
# Length: 2295, dtype: int64

# %%
quantity = df.groupby(["ctl_loading"]).size()
quantity_no_dub = df_no_dub.groupby(["ctl_loading"]).size()
weak_quantity_no_dub = weak_df_no_dub.groupby(["ctl_loading"]).size()

# %%
loadings = pd.concat([quantity, weak_quantity_no_dub, quantity_no_dub, aggregated_quantity, weak_aggregated_quantity_no_dublicates, aggregated_quantity_no_dublicates], axis=1).rename(columns={0: 'quan', 1: "quan_no_weak_dub", 2: 'quan_no_dub', 3: 'agg_quan', 4: "agg_quan_no_week_dub", 5: 'agg_quan_no_dub'})
loadings
# Out:
#              quan  quan_no_weak_dub  quan_no_dub  agg_quan  \
# ctl_loading
# 164246313     456               431          422       456
# 185831633      24                23           23       450
# 371367084     458               430          424       458
# 376949875     471               450          441       471
# 407853497     463               450          433       463
# ...           ...               ...          ...       ...
# 98292180110   455               431          426       455
# 98315908034   425               412          398       425
# 98338898542   451               422          417       451
# 98357067480   458               435          427       458
# 98467715900   447               426          418       447
#
#              agg_quan_no_week_dub  agg_quan_no_dub
# ctl_loading
# 164246313                     431              422
# 185831633                     435              399
# 371367084                     430              424
# 376949875                     450              441
# 407853497                     450              433
# ...                           ...              ...
# 98292180110                   431              426
# 98315908034                   412              398
# 98338898542                   422              417
# 98357067480                   435              427
# 98467715900                   426              418
#
# [2295 rows x 6 columns]

# %%
print([sum(loadings[value]) for value in loadings.columns])
# Out:
# [995004, 947926, 928150, 1044386, 994500, 972371]

# %%
df[df["date_of"] != df["ctl_loading_date"]]
# Out:
#                                 benchmark_id  \
# 22308   03B447D1-2B2D-4AC2-90C1-5DF2935D4FD1
# 22309   050C195A-1D74-402F-B36D-63CA40AFE789
# 22310   050C195A-1D74-402F-B36D-63CA40AFE789
# 22311   0532FCD2-5A26-4ED7-83C1-F482BE949312
# 22312   070B1DF3-5251-46A3-B706-B693B7148BC8
# ...                                      ...
# 990890  F68E9BE2-B3A2-4923-B648-14C424A84EF0
# 990891  F846C875-184D-4862-8C0E-5A5D58E4FD20
# 990892  FB5DFAD6-CF72-4C1A-B78C-EE42A1D0BFE0
# 990893  FCE411C7-6A5C-4AB3-8626-070844143139
# 990894  FDD3894E-BD97-45DB-B236-A2DB271FFFDA
#
#                                            benchmark_name    date_of  \
# 22308                    50%RUCBITRBB3Y + 50%RUCBITRBBB3Y 2018-05-28
# 22309                      60% RUGBITR1Y+40% RUONIA Index 2018-05-28
# 22310                      60% RUGBITR1Y+40% RUONIA Index 2018-05-28
# 22311   30.00%RUGBITR1Y + 1.10%ОФЗ-29006 + 68.90%ОФЗ-2... 2018-05-28
# 22312                                        Ставка 7,39% 2018-05-28
# ...                                                   ...        ...
# 990890                                          ОФЗ 24021 2024-03-05
# 990891                50%*RUGBITR3Y + 50%*Ставка 12.4174% 2024-03-05
# 990892                                        Ставка 7,7% 2024-03-05
# 990893                                          MBI TR 3Y 2024-03-05
# 990894                             70% EMCR + 30% B13TTRU 2024-03-05
#
#               quote  ctl_loading ctl_loading_date
# 22308     24.493686  12167897034       2018-05-29
# 22309    160.860394  12167897034       2018-05-29
# 22310    182.383826  12167897034       2018-05-29
# 22311    112.616041  12167897034       2018-05-29
# 22312    146.775892  12167897034       2018-05-29
# ...             ...          ...              ...
# 990890   912.681652  52363362374       2024-03-07
# 990891     7.432433  52363362374       2024-03-07
# 990892     2.477175  52363362374       2024-03-07
# 990893  1554.140295  52363362374       2024-03-07
# 990894   157.221460  52363362374       2024-03-07
#
# [84430 rows x 6 columns]

# %%
df.groupby(["date_of"]).size().plot(figsize=(25,5))
# Out:
# <Axes: xlabel='date_of'>

# %%
loadings_info = pd.read_csv("df_loadings.csv", parse_dates=["date_of", "ctl_loading_date"])[["ctl_loading", "date_of", "ctl_loading_date", "quantity"]]
loadings_info
# Out:
#       ctl_loading    date_of ctl_loading_date  quantity
# 0       164246313 2022-08-31       2022-08-31       456
# 1       185831633 2018-06-13       2021-08-27        24
# 2       371367084 2023-10-29       2023-10-29       458
# 3       376949875 2019-11-12       2019-11-12       471
# 4       407853497 2018-06-25       2018-06-26       463
# ...           ...        ...              ...       ...
# 2290  98292180110 2021-01-29       2021-01-29       455
# 2291  98315908034 2018-11-18       2018-11-20       425
# 2292  98338898542 2023-09-09       2023-09-09       451
# 2293  98357067480 2021-10-19       2021-10-19       458
# 2294  98467715900 2021-08-28       2021-08-28       447
#
# [2295 rows x 4 columns]

# %%
addloadings = loadings_info[loadings_info["date_of"] != loadings_info["ctl_loading_date"]]
addloadings
# Out:
#       ctl_loading    date_of ctl_loading_date  quantity
# 1       185831633 2018-06-13       2021-08-27        24
# 4       407853497 2018-06-25       2018-06-26       463
# 5       434605075 2022-09-06       2022-11-12        16
# 6       435359277 2023-08-11       2023-08-16       360
# 28     1504176871 2019-05-08       2019-05-13       420
# ...           ...        ...              ...       ...
# 2277  97607519920 2020-10-30       2020-11-02       458
# 2279  97737772288 2024-03-02       2024-03-07       496
# 2282  97968146715 2020-05-16       2020-05-21       206
# 2285  98149388334 2023-04-15       2023-11-21        11
# 2291  98315908034 2018-11-18       2018-11-20       425
#
# [289 rows x 4 columns]

# %%
len(addloadings["date_of"].unique())
# Out:
# 273

# %%
loadings_info.groupby(["date_of"]).size().sort_values()
# Out:
# date_of
# 2018-04-09    1
# 2022-03-08    1
# 2022-03-07    1
# 2022-03-06    1
# 2022-03-05    1
#              ..
# 2022-03-22    2
# 2018-11-17    3
# 2023-03-14    3
# 2023-08-12    3
# 2023-03-28    3
# Length: 2168, dtype: int64

# %%
loadings_info[loadings_info["date_of"] == pd.to_datetime("2023-04-15")]
# Out:
#       ctl_loading    date_of ctl_loading_date  quantity
# 285   12377336331 2023-04-15       2023-04-15       469
# 2285  98149388334 2023-04-15       2023-11-21        11

# %%
loadings_info.set_index("ctl_loading")[["date_of", "ctl_loading_date"]]
# Out:
#                date_of ctl_loading_date
# ctl_loading
# 164246313   2022-08-31       2022-08-31
# 185831633   2018-06-13       2021-08-27
# 371367084   2023-10-29       2023-10-29
# 376949875   2019-11-12       2019-11-12
# 407853497   2018-06-25       2018-06-26
# ...                ...              ...
# 98292180110 2021-01-29       2021-01-29
# 98315908034 2018-11-18       2018-11-20
# 98338898542 2023-09-09       2023-09-09
# 98357067480 2021-10-19       2021-10-19
# 98467715900 2021-08-28       2021-08-28
#
# [2295 rows x 2 columns]

# %%
loadings
# Out:
#              quan  quan_no_weak_dub  quan_no_dub  agg_quan  \
# ctl_loading
# 164246313     456               431          422       456
# 185831633      24                23           23       450
# 371367084     458               430          424       458
# 376949875     471               450          441       471
# 407853497     463               450          433       463
# ...           ...               ...          ...       ...
# 98292180110   455               431          426       455
# 98315908034   425               412          398       425
# 98338898542   451               422          417       451
# 98357067480   458               435          427       458
# 98467715900   447               426          418       447
#
#              agg_quan_no_week_dub  agg_quan_no_dub
# ctl_loading
# 164246313                     431              422
# 185831633                     435              399
# 371367084                     430              424
# 376949875                     450              441
# 407853497                     450              433
# ...                           ...              ...
# 98292180110                   431              426
# 98315908034                   412              398
# 98338898542                   422              417
# 98357067480                   435              427
# 98467715900                   426              418
#
# [2295 rows x 6 columns]

# %%
loadings_new = pd.concat([loadings_info.set_index("ctl_loading")[["date_of", "ctl_loading_date"]], loadings], axis=1)
loadings_new
# Out:
#                date_of ctl_loading_date  quan  quan_no_weak_dub  quan_no_dub  \
# ctl_loading
# 164246313   2022-08-31       2022-08-31   456               431          422
# 185831633   2018-06-13       2021-08-27    24                23           23
# 371367084   2023-10-29       2023-10-29   458               430          424
# 376949875   2019-11-12       2019-11-12   471               450          441
# 407853497   2018-06-25       2018-06-26   463               450          433
# ...                ...              ...   ...               ...          ...
# 98292180110 2021-01-29       2021-01-29   455               431          426
# 98315908034 2018-11-18       2018-11-20   425               412          398
# 98338898542 2023-09-09       2023-09-09   451               422          417
# 98357067480 2021-10-19       2021-10-19   458               435          427
# 98467715900 2021-08-28       2021-08-28   447               426          418
#
#              agg_quan  agg_quan_no_week_dub  agg_quan_no_dub
# ctl_loading
# 164246313         456                   431              422
# 185831633         450                   435              399
# 371367084         458                   430              424
# 376949875         471                   450              441
# 407853497         463                   450              433
# ...               ...                   ...              ...
# 98292180110       455                   431              426
# 98315908034       425                   412              398
# 98338898542       451                   422              417
# 98357067480       458                   435              427
# 98467715900       447                   426              418
#
# [2295 rows x 8 columns]

# %%
loadings_new[loadings_new["date_of"] == pd.to_datetime("2018-06-13")]
# Out:
#                date_of ctl_loading_date  quan  quan_no_weak_dub  quan_no_dub  \
# ctl_loading
# 185831633   2018-06-13       2021-08-27    24                23           23
# 72228790075 2018-06-13       2018-06-13   426               414          399
#
#              agg_quan  agg_quan_no_week_dub  agg_quan_no_dub
# ctl_loading
# 185831633         450                   435              399
# 72228790075       426                   414              399

# %%
# loadings_new.to_csv("loadings.csv", index=False)
